# %% [markdown]
# # Data Wrangling
# Problem Statement: Data Wrangling on Real Estate Market
# Dataset: "RealEstate_Prices.csv"
# Description: The dataset contains information about housing prices in a specific real estate
# market. It includes various attributes such as property characteristics, location, sale prices,
# and other relevant features. The goal is to perform data wrangling to gain insights into the
# factors influencing housing prices and prepare the dataset for further analysis or modeling.
# Tasks to Perform:
# 1. Import the "RealEstate_Prices.csv" dataset. Clean column names by removing spaces,
# special characters, or renaming them for clarity.
# 2. Handle missing values in the dataset, deciding on an appropriate strategy (e.g.,
# imputation or removal).
# 3. Perform data merging if additional datasets with relevant information are available
# (e.g., neighborhood demographics or nearby amenities).
# 4. Filter and subset the data based on specific criteria, such as a particular time period,
# property type, or location.
# 5. Handle categorical variables by encoding them appropriately (e.g., one-hot encoding or
# label encoding) for further analysis.
# 6. Aggregate the data to calculate summary statistics or derived metrics such as average
# sale prices by neighborhood or property type.
# 7. Identify and handle outliers or extreme values in the data that may affect the analysis
# or modeling process

# %% [markdown]
# Import the Dataset and Clean Column Names

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("RealEstate_Prices.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
# Clean column names
df.columns = df.columns.str.strip()  # Remove leading/trailing spaces
df.columns = df.columns.str.replace(' ', '_')  # Replace spaces with underscores
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
# Rename columns if needed for clarity
df.rename(columns={"stories": "floors"}, inplace=True)
df
# Out:
#         price  area  bedrooms  bathrooms  floors mainroad guestroom basement  \
# 0    13300000  7420         4          2       3      yes        no       no
# 1    12250000  8960         4          4       4      yes        no       no
# 2    12250000  9960         3          2       2      yes        no      yes
# 3    12215000  7500         4          2       2      yes        no      yes
# 4    11410000  7420         4          1       2      yes       yes      yes
# ..        ...   ...       ...        ...     ...      ...       ...      ...
# 540   1820000  3000         2          1       1      yes        no      yes
# 541   1767150  2400         3          1       1       no        no       no
# 542   1750000  3620         2          1       1      yes        no       no
# 543   1750000  2910         3          1       1       no        no       no
# 544   1750000  3850         3          1       2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %% [markdown]
# Handle Missing Values:

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# Data Merging (if additional datasets are available):

# %%
merged_df = df.merge(neighborhood_data, on="neighborhood_id", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\UNNATI~1\AppData\Local\Temp/ipykernel_15396/3428444370.py in <module>
# ----> 1 merged_df = df.merge(neighborhood_data, on="neighborhood_id", how="left")
#
# NameError: name 'neighborhood_data' is not defined

# %% [markdown]
# Filter and Subset Data

# %% [markdown]
# df = df[df['bedrooms'].between(3, 4)]
# df

# %% [markdown]
# Handle Categorical Variables

# %%
df = pd.get_dummies(df, columns=["furnishingstatus"])
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 534   2100000  3000         4          1        2      yes        no       no
# 537   1890000  1700         3          1        2      yes        no       no
# 541   1767150  2400         3          1        1       no        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea  \
# 0                no             yes        2      yes
# 1                no             yes        3       no
# 2                no              no        2      yes
# 3                no             yes        3      yes
# 4                no             yes        2       no
# ..              ...             ...      ...      ...
# 534              no              no        0       no
# 537              no              no        0       no
# 541              no              no        0       no
# 543              no              no        0       no
# 544              no              no        0       no
#
#      furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0                             1                                0
# 1                             1                                0
# 2                             0                                1
# 3                             1                                0
# 4                             1                                0
# ..                          ...                              ...
# 534                           0                                0
# 537                           0                                0
# 541                           0                                1
# 543                           1                                0
# 544                           0                                0
#
#      furnishingstatus_unfurnished
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 534                             1
# 537                             1
# 541                             0
# 543                             0
# 544                             1
#
# [395 rows x 15 columns]

# %% [markdown]
# Aggregate Data

# %%
# for any three attributes
agg_data = df[['price', 'area', 'bedrooms']].describe() 
agg_data
# Out:
#               price          area    bedrooms
# count  3.950000e+02    395.000000  395.000000
# mean   5.141029e+06   5312.106329    3.240506
# std    1.923055e+06   2158.410023    0.427933
# min    1.750000e+06   1650.000000    3.000000
# 25%    3.741500e+06   3640.000000    3.000000
# 50%    4.795000e+06   4992.000000    3.000000
# 75%    6.142500e+06   6540.000000    3.000000
# max    1.330000e+07  15600.000000    4.000000

# %%
# for all attributes
agg_data= df.describe()
agg_data
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  3.950000e+02    395.000000  395.000000  395.000000  395.000000
# mean   5.141029e+06   5312.106329    3.240506    1.351899    2.022785
# std    1.923055e+06   2158.410023    0.427933    0.533369    0.882421
# min    1.750000e+06   1650.000000    3.000000    1.000000    1.000000
# 25%    3.741500e+06   3640.000000    3.000000    1.000000    1.000000
# 50%    4.795000e+06   4992.000000    3.000000    1.000000    2.000000
# 75%    6.142500e+06   6540.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  15600.000000    4.000000    4.000000    4.000000
#
#           parking  furnishingstatus_furnished  \
# count  395.000000                  395.000000
# mean     0.769620                    0.265823
# std      0.898441                    0.442331
# min      0.000000                    0.000000
# 25%      0.000000                    0.000000
# 50%      0.000000                    0.000000
# 75%      2.000000                    1.000000
# max      3.000000                    1.000000
#
#        furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# count                       395.000000                    395.000000
# mean                          0.443038                      0.291139
# std                           0.497375                      0.454864
# min                           0.000000                      0.000000
# 25%                           0.000000                      0.000000
# 50%                           0.000000                      0.000000
# 75%                           1.000000                      1.000000
# max                           1.000000                      1.000000

# %% [markdown]
# To visulaize outliers

# %%
import matplotlib.pyplot as plt

# Create a scatterplot
plt.scatter(df['area'], df['price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatterplot of Price vs. Area')
plt.show()

# %% [markdown]
# Handle outliers

# %%
from scipy import stats

# %%
z_scores_price = stats.zscore(df['price'])
z_scores_area = stats.zscore(df['area'])

# %%
max_price = 1  # Example threshold (adjust as needed)
max_area = 12000  # Example threshold (adjust as needed)

# %%
df = df[(abs(z_scores_price) < max_price) & (abs(z_scores_area) < max_area)]
df
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 128  5873000   5500         3          1        3      yes       yes       no
# 129  5873000  11460         3          1        3      yes        no       no
# 130  5866000   4800         3          1        1      yes       yes      yes
# 131  5810000   5828         4          1        4      yes       yes       no
# 132  5810000   5200         3          1        3      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 336  3920000   8080         3          1        1      yes        no       no
# 337  3920000   2145         4          2        1      yes        no      yes
# 339  3885000   3180         4          2        2      yes        no       no
# 342  3850000   7152         3          1        2      yes        no       no
# 345  3850000   2015         3          1        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea  \
# 128              no             yes        1       no
# 129              no              no        2      yes
# 130              no              no        0       no
# 131              no              no        0       no
# 132              no             yes        0       no
# ..              ...             ...      ...      ...
# 336              no             yes        2       no
# 337              no              no        0      yes
# 339              no              no        0       no
# 342              no             yes        0       no
# 345              no              no        0      yes
#
#      furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 128                           1                                0
# 129                           0                                1
# 130                           0                                0
# 131                           0                                1
# 132                           0                                1
# ..                          ...                              ...
# 336                           0                                1
# 337                           0                                0
# 339                           1                                0
# 342                           1                                0
# 345                           0                                1
#
#      furnishingstatus_unfurnished
# 128                             0
# 129                             0
# 130                             1
# 131                             0
# 132                             0
# ..                            ...
# 336                             0
# 337                             1
# 339                             0
# 342                             0
# 345                             0
#
# [173 rows x 15 columns]
